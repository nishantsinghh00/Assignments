# %% [markdown]
# 1. Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5 navigation links that are properly placed within the navigation bar using the CSS box model. The navigation items must change their text color on hover.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem01.css">
</head>
<body>
    <header>
        <div id="navbar">
            <a href="#">Home</a>
            <a href="#">About Us</a>
            <a href="#">Contact</a>
            <a href="#">Blog</a>
            <a href="#">Login</a>
        </div>
    </header>
</body>
</html>

css file


* {
    margin: 0px;
    padding: 0px;
}
#navbar {
    border: 2px black solid;
    height: 50px;
    background-color: blue;
    padding-top: 25px;
}
a {
    color: white;
    margin: 40px;
}
a:hover { /*give hover effect*/
    color: red;
}

# %% [markdown]
# 2. Create a div centered with an image and paragraph similar to the image mentioned below.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem02.css">
</head>
<body>
    <div>
        <img src="https://blog.pwskills.com/wp-content/uploads/2023/12/MERN-FULL-STACK_CTA.png" alt="courseimage">
        <p><span>Course name: </span>PW SKills full stack web development</p>
    </div>
</body>
</html>

CSS file

* {
    margin: 0;
    padding: 0;
}
div {
    border: 2px solid black;
    display: inline-block;
    position: relative;
    left: 500px;
    width: 300px;
    top: 25px;
    padding: 15px;
    border-radius: 20px;
    background-color: rgb(221, 168, 10);
}
img {
    height: 300px;
    width: 300px;
    border-radius: 20px;
    margin-bottom: 10px;
}

# %% [markdown]
# 3. Create a navigation bar similar to question 1.For each navigation iteam, use a different border style.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem01.css">
</head>
<body>
    <header>
        <div id="navbar">
            <a href="#" id="firstiteam">Home</a>
            <a href="#" id="seconditeam">About Us</a>
            <a href="#" id="thirditeam">Contact</a>
            <a href="#" id="fourthiteam">Blog</a>
            <a href="#" id="fifthiteam">Login</a>
        </div>
    </header>
</body>
</html>

CSS file

* {
    margin: 0px;
    padding: 0px;
}
#navbar {
    border: 2px black solid;
    height: 50px;
    background-color: blue;
    padding-top: 25px;
}
a {
    color: white;
    margin: 40px;
}
a:hover { /*give hover effect*/
    color: red;
}
#firstiteam {
    border: 2px solid white;
    padding: 10px;
}
#seconditeam {
    border: 2px dotted white;
    padding: 10px;
}
#thirditeam {
    border: 2px dashed white;
    padding: 10px;
}
#fourthiteam {
    border: 2px double white;
    padding: 10px;
}
#fifthiteam {
    border: 2px outset white;
    padding: 10px;
}

# %% [markdown]
# 4.  Create simple webpage with an image and make the image circular using border radius.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem03.css">
</head>
<body>
    <img src="https://plus.unsplash.com/premium_photo-1676490672166-008dd4113e90?w=800&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxmZWF0dXJlZC1waG90b3MtZmVlZHw1fHx8ZW58MHx8fHx8" alt="random image">
</body>
</html>

CSS file

* {
    margin: 0;
    padding: 0;
}
img {
    height: 300px;
    width: 300px;
    margin-top: 25px;
    margin-left: 30px;
    border-radius: 300px;
}

# %% [markdown]
# 5.  Create a simple blog website about Goggle fonts. The webpage must have the heading with "Oswald" font align center to the page, below the heading have an image of Goggle fonts and a paragraph about Goggle font "Montserrat" paragraph font style should be "montserrat" font.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem04.css">
    <link href="https://fonts.googleapis.com/css2?family=Oswald&display=swap" rel="stylesheet">
</head>
<body>
    <header>
        <div id="navbar">
            <a href="#" id="firstiteam">Home</a>
            <a href="#" id="seconditeam">About Us</a>
            <span id="heading">goggle fonts blog</span>
            <a href="#" id="thirditeam">Contact Us</a>
            <a href="#" id="fourthitem">Login</a>
        </div>
    </header>
    <main>
       <section id="firstfont">
         <div id="firstfontheading">urdu fonts</div>
         <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEju01lmOfyIi4MZ6Bn5rrf74BBSrKhWeXW1fevvd6RY1-cS9zDPoFW8-8Dv4K6-6UCw197ClFO5eHtIgG3VCHKp8wJwhwqLgHzvmy9kzwKFZ1IIOJyokQ3C10yHw2bvZHBdMXx-r7gSDIjKKWUJ_LptJt4HXRDpcD_4sYzH53Nfaq5MLvxfgeYDeQT-/s3072/Urdu_blog_hero.png" alt="urdu font" id="firstfontimage">
         <p class="firstfontcontant">Urdu is the first language of over 70 million speakers and a second language to over 160 million people, mostly in Pakistan and India. Due to both design and engineering challenges, there were only a few typefaces available for the Urdu language in the preferred Nasta'liq writing style of the Arabic writing system. The scarcity of Nasta'liq typefaces was so dire that some newspapers and other printed materials were written by hand. Urdu speakers still sometimes write emails and messages in Romanized Urdu (the transliteration of Urdu in the Latin alphabet). </p>
         <div class="firstfontcontant">Why are there so few Urdu fonts? </div>
         <p class="firstfontcontant">If there is such a large population of Urdu speakers, you might wonder why there are so few typefaces for this population. One reason is that technology companies have not seen Urdu-speaking communities as important markets and have not invested resources to develop Nasta’liq typefaces. </p>
         <p class="firstfontcontant">Let’s go back in history and review some features of the Urdu language, the Nasta'liq script, and technological problems to find some more reasons.</p>
       </section>
       <section id="secondfont">
         <div id="secondfontheading">zen fonts</div>
         <div class="secondfontcontant">By Min-Young Kim</div>
         <p class="secondfontcontant">In 2019, Google Fonts started an ambitious project to expand its font library with a variety of typeface designs for Japanese. At that point Google Fonts had fewer than 10 Japanese families, most of which were basic Mincho (serif) and gothic (sans) designs. Since then the collection of Japanese fonts within the library has grown, now with 38 font families from 18 designers, in a variety of styles – from formal text types to fun display fonts. All these Japanese fonts are now live on Google Fonts for anyone to test out and use in any project.</p>
         <img src="https://lh3.googleusercontent.com/mVCCoSQbG082gv9CdhgtvLuX9GdbPqsOA_8U7x0rEkXp5rPvFMwhTh3iD1kUBCI5nEvhISPV3zwbR4o29xxZUokBR1xq5Wq2GaRUPVAKrXQXR2q3Oonw6uO4lrH1PvhL2Y2JhoJ1=w640-h320" alt="zenfont" id="secondfontimage">
         <p class="secondfontcontant">As part of this larger effort to expand Japanese offerings, Google Fonts collaborated with type designer Yoshimichi Ohira to open his prestigious collection of Zen Fonts typefaces to the public. With 23 Japanese and three Latin fonts in various styles of mincho (serif), gothic (sans serif), maru (rounded), and display styles, the Zen Fonts collection is now the largest set of Japanese fonts in Google Fonts’ expansive library, and is also available in Adobe Fonts. Check out The Story of Zen Fonts - interview with Yoshimichi Ohira to learn more.</p>
       </section>
       <section id="thirdfont">
         <div id="thirdfontheading">radio-canada's </div>
         <img src="https://lh4.googleusercontent.com/ngWaQj7v9DXpZ5Gof2u9U664T2h5losj4DzqSBF51cp_E-pZjLS9KiK9GNXax5iJFp-_HJbhhdD7GqwEFCs8T_PbvagvN3qnTs2YNq7F5crGEx4Gl7Ad-mhHXU7Q5iCTbSGoVCPSIi-hcqOGo3xjT3w=s16000" alt="fontimage" id="thirdfontimage">
         <p class="thirdfontcontant">A typeface made to give a specific identity and distinction to the Canadian Broadcasting Corporation (CBC) and Radio-Canada’s public broadcasting platforms is now available on Google Fonts in many languages using the Latin writing system, including many indigenous languages spoken in Canada. </p>
         <p class="thirdfontcontant">CBC/Radio-Canada is Canada's national public broadcaster. Its mandate is to inform, enlighten, entertain, and strengthen Canadian culture and diversity on radio, television, and digital platforms. As part of this mandate, CBC/Radio-Canada is proud to release its original typeface publicly and make it available through Google Fonts.</p>
         <p class="thirdfontcontant">The Radio-Canada typeface was created in 2017 by Montreal-based designer and typographer Charles Daoud, in collaboration with Coppers and Brasses and Alexandre Saumier Demers. </p>
         <p class="thirdfontcontant">The humanist style stands out with distinctive angles and subtle curves. In compliance with digital accessibility standards, the font’s x-height is intended to increase legibility, making it very effective when used in continuous text.</p>
       </section>
    </main>
</body>
</html>

CSS file

* {
    margin: 0;
    padding: 0;
}
#navbar {
    height: 80px;
    background-color: rgb(245, 233, 233);
}
#firstiteam {
    font-size: 25px;
    margin-left: 100px;
    text-decoration: none;
}
#seconditeam {
    font-size: 25px;
    margin-right: 130px;
    margin-left: 100px;
    text-decoration: none;
}
#heading {
    font-size: 60px;
    margin-right: 130px;
    text-transform: capitalize;
    text-decoration: none;
    font-weight: 900;
}
#thirditeam {
    font-size: 25px;
    margin-right: 100px;
    text-decoration: none;
}
#fourthitem {
    font-size: 25px;
    text-decoration: none;
}
a:hover {
    color: red;
}
#firstfontheading {
    font-size: 50px;
    font-weight: 600;
    margin-top: 100px;
    margin-bottom: 50px;
    text-decoration: underline;
    text-transform: capitalize;
    font-family: "Oswald";
}
#firstfontimage {
    height: 400px;
}
.firstfontcontant {
    font-size: 20px;
    font-family: "Montsserrat",sans-serif;
}
#secondfontheading {
    font-size: 50px;
    font-weight: 600;
    margin-top: 100px;
    margin-bottom: 50px;
    text-decoration: underline;
    text-transform: capitalize;
    font-family: "Oswald";
}
.secondfontcontant {
    font-size: 20px;
    font-family: "Montsserrat",sans-serif;
}
#secondfontimage {
    height: 400px;
}
#thirdfontheading {
    font-size: 50px;
    font-weight: 600;
    margin-top: 100px;
    margin-bottom: 50px;
    text-decoration: underline;
    text-transform: capitalize;
    font-family: "Oswald";
}
#thirdfontimage {
    height: 400px;
}
.thirdfontcontant{
    font-size: 20px;
    font-family: "Montsserrat",sans-serif;
}

# %% [markdown]
# 6.  Create a simple website as mentioned in the below image. You can get the assest by visiting https://pwskills.com/about-us.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem05.css">
</head>
<body>
    <header>
        <div id="navbar">
            <a href="#" id="navbarfirstiteam">Skills</a>
            <a href="#" id="navbarseconditeam">Courses</a>
            <a href="#" id="navbarthirditeam">IIT & IIM Online Programs</a>
            <a href="#" id="navbarfourthiteam">Masterclass</a>
            <input type="text" placeholder="Serch Course" id="navbarinput">
        </div>
    </header>
    <main>
        <div id="firstcontentheading">About Us</div>
        <p id="firstcontent">PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It". We aim to do this by providing exceptional up skilling courses at affordable rates, while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.</p>
        <img src="https://pwskills.com/images/aboutUs/aboutUs.png" alt="pwimage" id="firstcontentimage">
        <div id="secondcontentheading">Our Mission</div>
        <div id="secondcontentblock">
            <div id="secondcontent">PW Skills is the result of a continual effort to exponentially increase the employability of every Indian, irrespective of their socioeconomic status. With accessibility and affordability being the support structure of high-quality, industry-relevant courses, PW Skills aims to empower professionals and students alike to either jumpstart their careers or leverage existing skills with new, future-driven upgrades that will help them realise their full potential.</div>
        </div>
        <div id="thirdcontentheading">Our Services</div>
        <div id="thirdcontentblock">
            <div class="thirdcontent">
                <div class="thirdcontentitems">Affordable online courses</div>
                <div class="thirdcontentitemdiscription">Affordable online courses along with learning communities.</div>
            </div>
            <div class="thirdcontent">
                <div class="thirdcontentitems">Experience Portal</div>
                <div class="thirdcontentitemdiscription">A revolutionary self-paced experience portal.</div>
            </div>
            <div class="thirdcontent">
                <div class="thirdcontentitems">Innovation Lab for Tech products</div>
                <div class="thirdcontentitemdiscription">Product development at R&D lab with respect to robotics, drones, and customised products like electronic devices, AI on edge devices.</div>
            </div>
            <div class="thirdcontent">
                <div class="thirdcontentitems">Best in Class/Industry Mentors</div>
                <div class="thirdcontentitemdiscription">Mentors are Youtubers, digital entrepreneurs and content creators.</div>
            </div>
            <div class="thirdcontent">
                <div class="thirdcontentitems">On-Demand Courses</div>
                <div class="thirdcontentitemdiscription">Provide on-demand courses across technologies like data science, machine learning, and AI.</div>
            </div>
        </div>
    </main>
    <footer id="footbar">

    </footer>
</body>
</html>


CSS file


* {
    margin: 0;
    padding: 0;
}
#navbar {
    height: 70px;
    border: 2px solid white;
    border-style: outset;
    display: flex;
    justify-content: space-around;
}
a {
    text-decoration: none;
    color: black;
    padding-top: 20px;
}
#navbarinput {
    height: 40px;
    width: 250px;
    margin-top: 10px;
}
#navbarfirstiteam{
    font-weight: 900;
    font-size: 20px;
    text-transform: uppercase;
    letter-spacing: 1px;
}
#navbarfourthiteam {
    margin-right: 100px;
}
#firstcontentheading {
    margin-top: 50px;
    text-align: center;
    font-weight: 800;
    font-size: 40px;
}
#firstcontent {
    margin-top: 50px;
    padding-left: 80px;
    padding-right: 80px;
    font-size: 18px;
}
#firstcontentimage {
    padding-left: 80px;
    padding-right: 80px;
    width: 86%;
}
#secondcontentheading {
    margin-top: 65px;
    text-align: center;
    font-weight: 800;
    font-size: 40px;
}
#secondcontentblock {
    margin-top: 60px;
}
#secondcontent {
    display: inline-block;
    padding-left: 80px;
    width: 45%;
}
#thirdcontentheading {
    margin-top: 65px;
    text-align: center;
    font-weight: 800;
    font-size: 40px;
}
#thirdcontentblock{
    height: 300px;
    display: flex;
    flex-direction: column;
    justify-content: space-around;
    display: inline-block;
    margin-top: 60px;
}
.thirdcontent {
    display: inline-block;
    margin-left: 200px;
    padding: 20px;
}
.thirdcontentitems {
    font-size: 25px;
    font-weight: 800;
}
.thirdcontentitemdiscription {
    width: 400px;
}
#footbar {
    margin-top: 30px;
    height: 400px;
    background-color: black;
}

# %% [markdown]
# 7.  Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed. Use CSS opacity to acheive this output.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem06.css">
</head>
<body>
    <div id="posterblock">
        <div id="posterbackground"> <img src="https://blog.pwskills.com/wp-content/uploads/2023/12/MERN-FULL-STACK_CTA.png" alt="courseimage" id="posterimage">
        <div id="coursedetail">Course Name: PW Skills web development</div></div>
    </div>
</body>
</html>


CSS file


* {
    margin: 0;
    padding: 0;
}
#posterblock {
    border: 2px solid black;
    display: inline-block;
    margin-left: 100px;
    margin-top: 50px;
    height: 400px;
    width: 500px;
}
#posterbackground {
    margin: 50px;
    background-color: rgb(9, 189, 129);
    height: 280px;
    width: 350px;
    text-align: center;
    border-radius: 20px;
    opacity: 1;
    transition: opacity 0.3s ease;
}
#posterimage {
    height: 200px;
    width: 300px;
    margin-top: 30px;
}
#posterbackground:hover {
    opacity: 0.6;
}

# %% [markdown]
# 8.  Create a simple list of items as mentioned in the below image.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="./problem07.css">
</head>
<body>
    <div id="listblock">
        <div id="listheading">Requirements</div>
        <ol>
          <li>System with minimum i3 processor.</li>
          <li>At least 4GB of RAM.</li>
          <li>Working internet connection.</li>
          <li>Dedication to learn.</li>
        </ol>
    </div>
</body>
</html>


CSS file


* {
    margin: 0;
    padding: 0;
}
#listblock {
    display: inline-block;
    width: 700px;
    border: 2px solid black;
    margin: 50px;
    height: 280px;
}
#listheading {
    margin-bottom: 50px;
    margin-top: 10px;
    font-size: 50px;
    font-weight: 900;
    margin-left: 20px;
}
ol {
    margin-left: 80px;
    font-size: 25px;
    list-style-type: lower-roman;
}
